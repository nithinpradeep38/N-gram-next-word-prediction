# %% [markdown]
# ## Reuters data set
#
# Here is a brief about the dataset:
#
# - It contains documents belonging to 90 different categories
#
# - There are a total of 7769 training documents
#
# - And these documents contain 54716 sentences.
#
# ### Steps to build the next word recommender system
#
# 1. Loading and exploring the dataset
# 2. Text cleaning
# 3. Create vocabulary
# 4. Creating N-grams of the dialogue
# 5. Building an N-gram language model
# 6. Predicting the next word using N-gram Language Model
#
# #### Loading and exploring the dataset

# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.max_colwidth', None)


df= pd.read_csv('sample_reuters_dataset.csv')

# %%
df.head()
# Out:
#    sentence_number  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#
#                                                                                                                                                                                                                                                        sentence_text
# 0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .
# 1                                                                        They told Reuter correspondents in Asian capitals a U . S . Move against Japan might boost protectionist sentiment in the U . S . And lead to curbs on American imports of their products .
# 2                                                                                                                       But some exporters said that while the conflict would hurt them in the long - run , in the short - term Tokyo ' s loss might be their gain .
# 3                     The U . S . Has said it will impose 300 mln dlrs of tariffs on imports of Japanese electronics goods on April 17 , in retaliation for Japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost .
# 4                                                                 Unofficial Japanese estimates put the impact of the tariffs at 10 billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes .

# %%
#number of sentences
len(df)
# Out:
# 10000

# %% [markdown]
# #### Text Cleaning

# %%
def clean(text):
    #remove every character except alphabets, the apostophe and white spaces
    text= re.sub("[^a-zA-Z' ]", "", text)
    
    #convert to lowercase
    text= text.lower()
    
    return text
    
df['clean_sentence']= df['sentence_text'].apply(clean)

# %%
df.head()
# Out:
#    sentence_number  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#
#                                                                                                                                                                                                                                                        sentence_text  \
# 0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .
# 1                                                                        They told Reuter correspondents in Asian capitals a U . S . Move against Japan might boost protectionist sentiment in the U . S . And lead to curbs on American imports of their products .
# 2                                                                                                                       But some exporters said that while the conflict would hurt them in the long - run , in the short - term Tokyo ' s loss might be their gain .
# 3                     The U . S . Has said it will impose 300 mln dlrs of tariffs on imports of Japanese electronics goods on April 17 , in retaliation for Japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost .
# 4                                                                 Unofficial Japanese estimates put the impact of the tariffs at 10 billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes .
#
#                                                                                                                                                                                                                                               clean_sentence
# 0  asian exporters fear damage from u  s  japan rift mounting trade friction between the u  s  and japan has raised fears among many of asia ' s exporting nations that the row could inflict far  reaching economic damage  businessmen and officials said
# 1                                                                     they told reuter correspondents in asian capitals a u  s  move against japan might boost protectionist sentiment in the u  s  and lead to curbs on american imports of their products
# 2                                                                                                                   but some exporters said that while the conflict would hurt them in the long  run  in the short  term tokyo ' s loss might be their gain
# 3                      the u  s  has said it will impose  mln dlrs of tariffs on imports of japanese electronics goods on april   in retaliation for japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost
# 4                                                            unofficial japanese estimates put the impact of the tariffs at  billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes

# %% [markdown]
# #### Create vocabulary

# %%
word_dict= {}
for i in range(len(df)):
    text= df.loc[i,'clean_sentence'].split()
    
    for token in text:
        if token in word_dict:
            word_dict[token]+=1
        else:
            word_dict[token]=1
    
    
word_dict
# Out:
# {'asian': 13,
#  'exporters': 52,
#  'fear': 8,
#  'damage': 29,
#  'from': 1369,
#  'u': 1117,
#  's': 2864,
#  'japan': 441,
#  'rift': 1,
#  'mounting': 5,
#  'trade': 549,
#  'friction': 8,
#  'between': 191,
#  'the': 12496,
#  'and': 4599,
#  'has': 974,
#  'raised': 70,
#  'fears': 13,
#  'among': 44,
#  'many': 54,
#  'of': 6671,
#  'asia': 14,
#  "'": 2094,
#  'exporting': 12,
#  'nations': 71,
#  'that': 1376,
#  'row': 3,
#  'could': 291,
#  'inflict': 1,
#  'far': 55,
#  'reaching': 7,
#  'economic': 244,
#  'businessmen': 15,
#  'officials': 190,
#  'said': 4649,
#  'they': 518,
#  'told': 237,
#  'reuter': 27,
#  'correspondents': 3,
#  'in': 5070,
#  'capitals': 3,
#  'a': 4412,
#  'move': 101,
#  'against': 270,
#  'might': 59,
#  'boost': 45,
#  'protectionist': 22,
#  'sentiment': 10,
#  'lead': 96,
#  'to': 6337,
#  'curbs': 12,
#  'on': 1643,
#  'american': 126,
#  'imports': 242,
#  'their': 230,
#  'products': 200,
#  'but': 650,
#  'some': 278,
#  'while': 164,
#  'conflict': 3,
#  'would': 926,
#  'hurt': 11,
#  'them': 58,
#  'long': 119,
#  'run': 21,
#  'short': 87,
#  'term': 120,
#  'tokyo': 75,
#  'loss': 607,
#  'be': 1165,
#  'gain': 101,
#  'it': 1970,
#  'will': 984,
#  'impose': 20,
#  'mln': 3064,
#  'dlrs': 2140,
#  'tariffs': 82,
#  'japanese': 192,
#  'electronics': 25,
#  'goods': 69,
#  'april': 477,
#  'retaliation': 20,
#  'for': 2592,
#  'alleged': 11,
#  'failure': 23,
#  'stick': 1,
#  'pact': 59,
#  'not': 838,
#  'sell': 139,
#  'semiconductors': 9,
#  'world': 166,
#  'markets': 182,
#  'at': 1311,
#  'below': 66,
#  'cost': 86,
#  'unofficial': 1,
#  'estimates': 62,
#  'put': 59,
#  'impact': 52,
#  'billion': 1112,
#  'spokesmen': 3,
#  'major': 206,
#  'firms': 57,
#  'virtually': 14,
#  'halt': 10,
#  'exports': 294,
#  'hit': 37,
#  'by': 1375,
#  'new': 474,
#  'taxes': 29,
#  'we': 258,
#  'wouldn': 6,
#  't': 115,
#  'able': 31,
#  'do': 90,
#  'business': 171,
#  'spokesman': 166,
#  'leading': 49,
#  'firm': 114,
#  'matsushita': 1,
#  'electric': 35,
#  'industrial': 120,
#  'co': 370,
#  'ltd': 273,
#  'lt': 1498,
#  'mc': 1,
#  'if': 282,
#  'remain': 55,
#  'place': 31,
#  'any': 142,
#  'length': 1,
#  'time': 145,
#  'beyond': 12,
#  'few': 42,
#  'months': 164,
#  'mean': 11,
#  'complete': 22,
#  'erosion': 2,
#  'subject': 72,
#  'tom': 4,
#  'murtha': 1,
#  'stock': 394,
#  'analyst': 60,
#  'office': 44,
#  'broker': 21,
#  'james': 33,
#  'capel': 2,
#  'taiwan': 62,
#  'are': 625,
#  'also': 442,
#  'worried': 15,
#  'aware': 7,
#  'seriousness': 3,
#  'threat': 11,
#  'because': 214,
#  'serves': 3,
#  'as': 884,
#  'warning': 5,
#  'us': 41,
#  'senior': 40,
#  'taiwanese': 4,
#  'official': 174,
#  'who': 98,
#  'asked': 74,
#  'named': 38,
#  'had': 512,
#  'surplus': 155,
#  'last': 654,
#  'year': 1212,
#  'pct': 1811,
#  'with': 1127,
#  'helped': 21,
#  'swell': 2,
#  'foreign': 253,
#  'exchange': 279,
#  'reserves': 153,
#  'largest': 79,
#  'must': 46,
#  'quickly': 18,
#  'open': 98,
#  'our': 101,
#  'remove': 9,
#  'barriers': 12,
#  'cut': 206,
#  'import': 67,
#  'allow': 40,
#  'want': 43,
#  'defuse': 2,
#  'problems': 55,
#  'possible': 72,
#  'paul': 21,
#  'sheen': 1,
#  'chairman': 145,
#  'textile': 32,
#  'safe': 3,
#  'group': 342,
#  'south': 135,
#  'korea': 49,
#  'promotion': 5,
#  'association': 53,
#  'dispute': 24,
#  'pressure': 57,
#  'whose': 21,
#  'chief': 51,
#  'similar': 36,
#  'those': 75,
#  'up': 386,
#  'malaysia': 21,
#  'officers': 17,
#  'tough': 23,
#  'hard': 37,
#  'producers': 72,
#  'third': 67,
#  'countries': 142,
#  'expand': 25,
#  'sales': 371,
#  'hong': 26,
#  'kong': 26,
#  'where': 60,
#  'newspapers': 5,
#  'have': 542,
#  'been': 396,
#  'selling': 42,
#  'manufacturers': 15,
#  'share': 516,
#  'view': 40,
#  'other': 331,
#  'such': 100,
#  'commercial': 41,
#  'advantage': 8,
#  'outweighed': 2,
#  'further': 172,
#  'block': 19,
#  'is': 1420,
#  'very': 72,
#  'lawrence': 2,
#  'mills': 17,
#  'director': 41,
#  'general': 86,
#  'federation': 20,
#  'industry': 200,
#  'whole': 20,
#  'purpose': 9,
#  'prevent': 30,
#  'one': 508,
#  'day': 132,
#  'extended': 19,
#  'sources': 161,
#  'much': 92,
#  'more': 354,
#  'serious': 13,
#  'disadvantage': 2,
#  'action': 82,
#  'restraining': 2,
#  'he': 971,
#  'was': 1127,
#  'biggest': 24,
#  'export': 152,
#  'market': 498,
#  'accounting': 24,
#  'over': 236,
#  'domestically': 5,
#  'produced': 45,
#  'australian': 56,
#  'government': 304,
#  'awaiting': 9,
#  'outcome': 12,
#  'talks': 112,
#  'interest': 252,
#  'concern': 39,
#  'minister': 122,
#  'john': 24,
#  'button': 2,
#  'canberra': 1,
#  'friday': 44,
#  'this': 642,
#  'kind': 13,
#  'deterioration': 6,
#  'relations': 13,
#  'two': 444,
#  'which': 643,
#  'trading': 141,
#  'partners': 57,
#  'ours': 2,
#  'matter': 16,
#  'australia': 55,
#  'concerns': 9,
#  'centred': 1,
#  'coal': 7,
#  'beef': 57,
#  'significant': 34,
#  'country': 103,
#  'meanwhile': 13,
#  'diplomatic': 10,
#  'manoeuvres': 1,
#  'solve': 5,
#  'stand': 14,
#  'off': 89,
#  'continue': 84,
#  'ruling': 30,
#  'liberal': 18,
#  'democratic': 17,
#  'party': 34,
#  'yesterday': 161,
#  'outlined': 12,
#  'package': 34,
#  'measures': 67,
#  'economy': 125,
#  'proposed': 106,
#  'include': 65,
#  'large': 70,
#  'supplementary': 5,
#  'budget': 117,
#  'record': 188,
#  'public': 84,
#  'works': 12,
#  'spending': 54,
#  'first': 447,
#  'half': 113,
#  'financial': 148,
#  'call': 28,
#  'stepped': 2,
#  'an': 844,
#  'emergency': 10,
#  'measure': 16,
#  'stimulate': 27,
#  'despite': 71,
#  'prime': 73,
#  'yasuhiro': 12,
#  'nakasone': 24,
#  'avowed': 1,
#  'fiscal': 90,
#  'reform': 31,
#  'program': 66,
#  'deputy': 16,
#  'representative': 19,
#  'michael': 12,
#  'smith': 12,
#  'makoto': 3,
#  'kuroda': 9,
#  'international': 221,
#  'miti': 17,
#  'due': 160,
#  'meet': 63,
#  'washington': 92,
#  'week': 334,
#  'effort': 31,
#  'end': 275,
#  'china': 106,
#  'daily': 65,
#  'says': 143,
#  'vermin': 2,
#  'eat': 2,
#  'grain': 130,
#  'stocks': 177,
#  'survey': 8,
#  'provinces': 6,
#  'seven': 147,
#  'cities': 4,
#  'showed': 48,
#  'consume': 3,
#  'each': 119,
#  'tonnes': 535,
#  'or': 553,
#  'fruit': 3,
#  'output': 107,
#  'left': 28,
#  'rot': 3,
#  'its': 1372,
#  'vegetables': 4,
#  'paper': 27,
#  'blamed': 7,
#  'waste': 14,
#  'inadequate': 10,
#  'storage': 18,
#  'bad': 6,
#  'preservation': 2,
#  'methods': 6,
#  'launched': 20,
#  'national': 197,
#  'programme': 13,
#  'reduce': 77,
#  'calling': 10,
#  'improved': 41,
#  'technology': 40,
#  'greater': 23,
#  'production': 289,
#  'additives': 2,
#  'gave': 44,
#  'no': 277,
#  'details': 57,
#  'revise': 8,
#  'energy': 93,
#  'demand': 177,
#  'downwards': 4,
#  'ministry': 108,
#  'supply': 158,
#  'outlook': 28,
#  'august': 39,
#  'forecast': 96,
#  'downtrend': 2,
#  'expected': 274,
#  'lower': 152,
#  'projection': 6,
#  'primary': 26,
#  'supplies': 60,
#  'kilolitres': 1,
#  'kl': 2,
#  'decision': 70,
#  'follows': 45,
#  'emergence': 1,
#  'structural': 8,
#  'changes': 43,
#  'following': 75,
#  'rise': 240,
#  'value': 106,
#  'yen': 193,
#  'decline': 74,
#  'domestic': 164,
#  'power': 30,
#  'planning': 24,
#  'work': 40,
#  'out': 148,
#  'revised': 45,
#  'through': 120,
#  'deliberations': 1,
#  'committee': 74,
#  'meetings': 29,
#  'agency': 38,
#  'natural': 50,
#  'resources': 43,
#  'review': 36,
#  'breakdown': 8,
#  'including': 101,
#  'oil': 586,
#  'nuclear': 2,
#  'gas': 158,
#  'provided': 25,
#  'bulk': 17,
#  'ended': 144,
#  'march': 315,
#  'supplying': 5,
#  'estimated': 105,
#  'kilowatt': 1,
#  'hour': 10,
#  'basis': 70,
#  'followed': 23,
#  'liquefied': 3,
#  'noted': 61,
#  'thai': 15,
#  'deficit': 213,
#  'widens': 3,
#  'quarter': 377,
#  'thailand': 27,
#  'widened': 6,
#  'baht': 3,
#  'ago': 129,
#  'economics': 9,
#  'department': 183,
#  'janunary': 1,
#  'rose': 227,
#  'climate': 4,
#  'resulted': 20,
#  'increase': 221,
#  'raw': 20,
#  'materials': 45,
#  'semi': 12,
#  'finished': 8,
#  'bill': 70,
#  'however': 137,
#  'fell': 126,
#  'prices': 387,
#  'expanded': 7,
#  'growth': 258,
#  'smaller': 17,
#  'than': 366,
#  'earnings': 177,
#  'key': 51,
#  'commodities': 30,
#  'rice': 72,
#  'declined': 61,
#  'maize': 41,
#  'sugar': 130,
#  'tin': 51,
#  'canned': 4,
#  'pineapples': 1,
#  'registering': 3,
#  'high': 150,
#  'were': 597,
#  'jewellery': 1,
#  'clothing': 4,
#  'rubber': 36,
#  'indonesia': 46,
#  'sees': 76,
#  'cpo': 5,
#  'price': 397,
#  'rising': 73,
#  'sharply': 46,
#  'expects': 98,
#  'crude': 160,
#  'palm': 32,
#  'tonne': 75,
#  'fob': 14,
#  'sometime': 3,
#  'better': 41,
#  'european': 121,
#  'fall': 111,
#  'malaysian': 11,
#  'hasrul': 1,
#  'harahap': 3,
#  'junior': 4,
#  'tree': 2,
#  'crops': 33,
#  'indonesian': 10,
#  'reporters': 47,
#  'sumatran': 1,
#  'now': 173,
#  'around': 164,
#  'cif': 7,
#  'delivery': 58,
#  'rotterdam': 13,
#  'traders': 133,
#  'maintain': 37,
#  'making': 73,
#  'recent': 102,
#  'purchases': 33,
#  'so': 103,
#  'possibly': 19,
#  'second': 82,
#  'producer': 59,
#  'after': 367,
#  'forced': 16,
#  'ensure': 9,
#  'during': 110,
#  'moslem': 1,
#  'fasting': 2,
#  'month': 250,
#  'ramadan': 2,
#  'cover': 28,
#  'temporary': 24,
#  'shortage': 20,
#  'lose': 7,
#  'calendar': 18,
#  'according': 54,
#  'central': 193,
#  'bank': 616,
#  'figures': 118,
#  'ship': 16,
#  'ban': 21,
#  'ends': 15,
#  'nsw': 10,
#  'ports': 18,
#  'tug': 5,
#  'crews': 3,
#  'wales': 5,
#  'victoria': 3,
#  'western': 68,
#  'lifted': 15,
#  'flag': 9,
#  'ships': 36,
#  'carrying': 12,
#  'containers': 2,
#  'still': 112,
#  'being': 97,
#  'disrupted': 7,
#  'separate': 19,
#  'shipping': 25,
#  'imposed': 26,
#  'pay': 151,
#  'claim': 8,
#  'prevented': 7,
#  'movement': 20,
#  'port': 50,
#  'nearly': 34,
#  'vessels': 20,
#  'went': 25,
#  'before': 141,
#  'hearing': 14,
#  'arbitration': 3,
#  'commission': 111,
#  'today': 275,
#  'disruption': 3,
#  'began': 46,
#  'cargo': 20,
#  'handling': 8,
#  'sydney': 5,
#  'newcastle': 3,
#  'kembla': 3,
#  'part': 96,
#  'called': 62,
#  'trades': 14,
#  'labour': 15,
#  'council': 58,
#  'protest': 9,
#  'state': 112,
#  'workers': 54,
#  'compensation': 12,
#  'laws': 14,
#  'various': 19,
#  'unions': 11,
#  'appear': 16,
#  'taking': 38,
#  'turn': 12,
#  'start': 100,
#  'shift': 10,
#  'then': 42,
#  'walk': 1,
#  'container': 4,
#  'movements': 9,
#  'most': 108,
#  'affected': 39,
#  'stopped': 9,
#  'altogether': 4,
#  'say': 97,
#  'how': 41,
#  'go': 43,
#  'what': 77,
#  'effect': 45,
#  'commodity': 49,
#  'may': 540,
#  'likely': 106,
#  'least': 45,
#  'paian': 1,
#  'nainggolan': 3,
#  'reuters': 92,
#  'telephone': 24,
#  'interview': 22,
#  'sawn': 1,
#  'timber': 5,
#  'pepper': 1,
#  'tobacco': 19,
#  'considered': 21,
#  'either': 22,
#  'refined': 23,
#  'introduced': 23,
#  'question': 19,
#  'rachmat': 1,
#  'saleh': 2,
#  'when': 169,
#  'ahead': 28,
#  'made': 174,
#  'fledgling': 1,
#  'currently': 57,
#  'coffee': 71,
#  'physicals': 3,
#  'outcry': 1,
#  'system': 102,
#  'four': 168,
#  'days': 128,
#  'several': 82,
#  'factors': 31,
#  'make': 91,
#  'cautiously': 2,
#  'slowly': 7,
#  'safely': 1,
#  'mistake': 2,
#  'undermine': 5,
#  'confidence': 21,
#  'physical': 9,
#  'added': 219,
#  'january': 106,
#  'contracts': 42,
#  'traded': 27,
#  'five': 245,
#  'forward': 29,
#  'robusta': 2,
#  'grades': 16,
#  'prompt': 2,
#  'board': 184,
#  'considering': 32,
#  'introduction': 10,
#  'futures': 64,
#  'later': 55,
#  'feasibility': 3,
#  'study': 28,
#  'needed': 50,
#  'decisions': 13,
#  'until': 62,
#  'elections': 6,
#  'monday': 25,
#  'should': 146,
#  'marketing': 72,
#  'hoped': 14,
#  'development': 89,
#  'help': 80,
#  'trying': 26,
#  'overseas': 25,
#  'building': 42,
#  'contacts': 5,
#  'users': 7,
#  'teams': 1,
#  'already': 82,
#  'encourage': 17,
#  'direct': 15,
#  'use': 119,
#  'delegation': 9,
#  'visit': 17,
#  'europe': 45,
#  'mexico': 22,
#  'latin': 4,
#  'states': 145,
#  'participation': 7,
#  'infant': 1,
#  'good': 71,
#  'although': 66,
#  'disappointing': 4,
#  'transactions': 24,
#  'december': 89,
#  'totalled': 26,
#  'worth': 51,
#  'plus': 32,
#  'rupiah': 3,
#  'delivered': 9,
#  'locally': 2,
#  'latest': 66,
#  'report': 209,
#  'amounted': 6,
#  'only': 175,
#  'lots': 4,
#  'valued': 15,
#  'total': 293,
#  'membership': 8,
#  'nine': 111,
#  'brokers': 25,
#  'sri': 14,
#  'lanka': 13,
#  'gets': 11,
#  'usda': 108,
#  'approval': 65,
#  'wheat': 189,
#  'food': 52,
#  'agriculture': 130,
#  'approved': 64,
#  'continental': 25,
#  'sale': 147,
#  'soft': 23,
#  'c': 76,
#  'f': 52,
#  'pacific': 39,
#  'northwest': 10,
#  'colombo': 6,
#  'shipment': 32,
#  'mining': 40,
#  'gold': 99,
#  'mine': 50,
#  'corp': 623,
#  'holdings': 56,
#  'wmng': 2,
#  'wmc': 6,
#  'establish': 5,
#  'joint': 55,
#  'venture': 46,
#  'northern': 19,
#  'territory': 2,
#  'about': 515,
#  'known': 23,
#  'goodall': 1,
#  'project': 14,
#  'owned': 125,
#  'local': 53,
#  'w': 17,
#  'r': 17,
#  'grace': 11,
#  'gra': 3,
#  'unit': 171,
#  'located': 15,
#  'kms': 2,
#  'east': 52,
#  'adelaide': 1,
#  'river': 23,
#  'mt': 11,
#  'bundey': 1,
#  'statement': 168,
#  'pit': 2,
#  'conventional': 3,
#  'leach': 1,
#  'treatment': 9,
#  'plant': 66,
#  'produce': 28,
#  'ounces': 17,
#  'mid': 26,
#  'annual': 101,
#  'ore': 24,
#  'capacity': 42,
#  'sumitomo': 16,
#  'aims': 6,
#  'quick': 7,
#  'recovery': 25,
#  'merger': 128,
#  'sumi': 1,
#  'certain': 63,
#  'status': 15,
#  'profitable': 21,
#  'result': 86,
#  'heiwa': 4,
#  'sogo': 4,
#  'analysts': 185,
#  'osaka': 2,
#  'based': 142,
#  'desposits': 1,
#  'trillion': 4,
#  'merged': 6,
#  'small': 40,
#  'struggling': 3,
#  'unrecoverable': 1,
#  'loans': 118,
#  'october': 53,
#  'link': 14,
#  'president': 137,
#  'koh': 1,
#  'komatsu': 9,
#  'confident': 9,
#  'his': 105,
#  'can': 116,
#  'regain': 1,
#  'position': 67,
#  'll': 4,
#  'back': 50,
#  'within': 63,
#  'three': 277,
#  'years': 159,
#  'initially': 8,
#  'profitability': 5,
#  'efficiency': 8,
#  'vastly': 1,
#  'branch': 10,
#  'network': 18,
#  'metropolitan': 4,
#  'area': 61,
#  'relatively': 16,
#  'weak': 24,
#  'divided': 9,
#  'whether': 52,
#  'gamble': 3,
#  'paid': 65,
#  'too': 53,
#  'debts': 4,
#  'others': 18,
#  'argue': 4,
#  'effective': 91,
#  'creating': 1,
#  'comparable': 10,
#  'scratch': 1,
#  'agreed': 155,
#  'aggressive': 8,
#  'entered': 32,
#  'lucrative': 4,
#  'securities': 151,
#  'geared': 2,
#  'competition': 21,
#  'questioned': 4,
#  'wisdom': 1,
#  'moves': 36,
#  've': 14,
#  'bold': 3,
#  'everything': 3,
#  'largely': 15,
#  'hands': 11,
#  'kleinwort': 5,
#  'benson': 2,
#  'simon': 3,
#  'smithson': 2,
#  'limits': 21,
#  'placed': 18,
#  'enter': 8,
#  'investment': 161,
#  'goldman': 5,
#  'sachs': 5,
#  'limited': 34,
#  'partnership': 30,
#  'federal': 145,
#  'reserve': 109,
#  'forbidden': 1,
#  'personnel': 7,
#  'tie': 4,
#  'widely': 7,
#  'looked': 5,
#  'lame': 1,
#  'duck': 1,
#  'fed': 165,
#  'stricter': 1,
#  'regulations': 12,
#  'change': 80,
#  'near': 41,
#  'future': 51,
#  'things': 7,
#  'wait': 4,
#  'st': 281,
#  'century': 13,
#  'willing': 13,
#  'patient': 4,
#  'routes': 7,
#  'into': 186,
#  'home': 43,
#  'article': 8,
#  'act': 32,
#  'version': 3,
#  'glass': 3,
#  'steagall': 1,
#  'separates': 2,
#  'banking': 54,
#  'walls': 1,
#  'crumbling': 1,
#  'hopes': 21,
#  'deregulation': 10,
#  'create': 7,
#  'opportunities': 12,
#  'need': 49,
#  'find': 22,
#  'chances': 5,
#  'cases': 12,
#  'these': 87,
#  'related': 28,
#  'trust': 56,
#  'occur': 10,
#  'focus': 16,
#  'bond': 50,
#  'dealing': 3,
#  'strengthening': 10,
#  'meiko': 1,
#  'holds': 32,
#  'optimistic': 18,
#  'entering': 8,
#  'here': 67,
#  'swiss': 40,
#  'universal': 8,
#  'subsidiary': 132,
#  'banca': 1,
#  'del': 9,
#  'gottardo': 2,
#  'finance': 112,
#  'grant': 6,
#  'licences': 12,
#  'subsidiaries': 19,
#  'banks': 149,
#  'soon': 36,
#  'parent': 26,
#  'less': 91,
#  'reluctant': 9,
#  'push': 14,
#  'don': 40,
#  'waves': 1,
#  'expect': 49,
#  'allowed': 22,
#  'like': 37,
#  'city': 38,
#  'pushing': 7,
#  'lending': 19,
#  'individuals': 8,
#  'medium': 27,
#  'businesses': 49,
#  'replace': 9,
#  'disappearing': 1,
#  'big': 15,
#  'devote': 1,
#  'lot': 16,
#  'digesting': 1,
#  'initiatives': 5,
#  'ailing': 3,
#  'strategies': 2,
#  'absorbing': 1,
#  'juggling': 1,
#  'next': 155,
#  'decade': 5,
#  'see': 58,
#  'strategy': 25,
#  'right': 33,
#  'wrong': 4,
#  'subroto': 3,
#  'supports': 6,
#  'extension': 24,
#  'mines': 25,
#  'confirmed': 22,
#  'support': 71,
#  'sixth': 10,
#  'agreement': 258,
#  'ita': 7,
#  'necessary': 24,
#  'clarify': 2,
#  'lapse': 2,
#  'ready': 15,
#  'seventh': 7,
#  'accord': 60,
#  'believe': 41,
#  'unnecessary': 2,
#  'expire': 17,
#  'june': 238,
#  'unless': 28,
#  'thirds': 5,
#  'majority': 24,
#  'members': 49,
#  'vote': 18,
#  'bundesbank': 84,
#  'allocates': 2,
#  'marks': 82,
#  'tender': 147,
#  'accepted': 23,
#  'bids': 33,
#  'repurchase': 49,
#  'fixed': 47,
#  ...}

# %%
words_df= pd.DataFrame({'word': list(word_dict.keys()), 'count': list(word_dict.values())})
words_df= words_df.sort_values(by= 'count', ascending=False)
words_df.reset_index(inplace=True, drop=True)

# %%
words_df.head() #most frequent words
# Out:
#    word  count
# 0   the  12496
# 1    of   6671
# 2    to   6337
# 3    in   5070
# 4  said   4649

# %%
words_df.tail() #least frequent words
# Out:
#               word  count
# 12575  shareholdrs      1
# 12576         disc      1
# 12577      asylums      1
# 12578        benel      1
# 12579           sb      1

# %%
len(words_df)
# Out:
# 12580

# %% [markdown]
# We have 12580 words in the vocabulary based on which we will build the N-gram model.

# %% [markdown]
# #### Creating N-gram model

# %%
def create_unigram(sentence):
    #creating tokens from the sentence
    tokens= sentence.split()
    #empty list to store the unigrams
    unigram_list= []
    #number of unigrams= no. of tokens in the sentence
    for i in range(len(tokens)):
        #appending each unigram in the list
        unigram_list.append(tokens[i:i+1])
        
        #returning the unigram list for a sentece
    return unigram_list

# %%
# creating unigrams for all the sentences in the dataset 
final_unigram = []
# for each sentence
for i in range(len(df)):
    # using the defined unigram function to create unigrams
    final_unigram.append(create_unigram(df['clean_sentence'][i]))

# adding the unigram in a seperate column in the dataset
df['unigram'] = final_unigram

# %%
def create_bigram(sentence):
    #creating tokens from the sentence
    tokens= sentence.split()
    #empty list to store the unigrams
    bigram_list= []
    #number of bigrams= no. of tokens in the sentence-1
    for i in range(len(tokens)-1):
        #appending each bigram in the list
        bigram_list.append(tokens[i:i+2])
        
        #returning the bigram list for a sentece
    return bigram_list

# creating bigrams for all the sentences in the dataset 
final_bigram = []
# for each sentence
for i in range(len(df)):
    # using the defined bigram function to create unigrams
    final_bigram.append(create_bigram(df['clean_sentence'][i]))

# adding the bigram in a seperate column in the dataset
df['bigram'] = final_bigram

# %%
def create_trigram(sentence):
    #creating tokens from the sentence
    tokens= sentence.split()
    #empty list to store the unigrams
    trigram_list= []
    #number of trigrams= no. of tokens in the sentence-2
    for i in range(len(tokens)-2):
        #appending each trigram in the list
        trigram_list.append(tokens[i:i+3])
        
        #returning the unigram list for a sentece
    return trigram_list

# creating trigrams for all the sentences in the dataset 
final_trigram = []
# for each sentence
for i in range(len(df)):
    # using the defined unigram function to create trigrams
    final_trigram.append(create_trigram(df['clean_sentence'][i]))

# adding the trigram in a seperate column in the dataset
df['trigram'] = final_trigram

# %%
df.head()
# Out:
#    sentence_number  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#
#                                                                                                                                                                                                                                                        sentence_text  \
# 0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPAN RIFT Mounting trade friction between the U . S . And Japan has raised fears among many of Asia ' s exporting nations that the row could inflict far - reaching economic damage , businessmen and officials said .
# 1                                                                        They told Reuter correspondents in Asian capitals a U . S . Move against Japan might boost protectionist sentiment in the U . S . And lead to curbs on American imports of their products .
# 2                                                                                                                       But some exporters said that while the conflict would hurt them in the long - run , in the short - term Tokyo ' s loss might be their gain .
# 3                     The U . S . Has said it will impose 300 mln dlrs of tariffs on imports of Japanese electronics goods on April 17 , in retaliation for Japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost .
# 4                                                                 Unofficial Japanese estimates put the impact of the tariffs at 10 billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes .
#
#                                                                                                                                                                                                                                               clean_sentence  \
# 0  asian exporters fear damage from u  s  japan rift mounting trade friction between the u  s  and japan has raised fears among many of asia ' s exporting nations that the row could inflict far  reaching economic damage  businessmen and officials said
# 1                                                                     they told reuter correspondents in asian capitals a u  s  move against japan might boost protectionist sentiment in the u  s  and lead to curbs on american imports of their products
# 2                                                                                                                   but some exporters said that while the conflict would hurt them in the long  run  in the short  term tokyo ' s loss might be their gain
# 3                      the u  s  has said it will impose  mln dlrs of tariffs on imports of japanese electronics goods on april   in retaliation for japan ' s alleged failure to stick to a pact not to sell semiconductors on world markets at below cost
# 4                                                            unofficial japanese estimates put the impact of the tariffs at  billion dlrs and spokesmen for major electronics firms said they would virtually halt exports of products hit by the new taxes
#
#                                                                                                                                                                                                                                                                                                                                                                              unigram  \
# 0  [[asian], [exporters], [fear], [damage], [from], [u], [s], [japan], [rift], [mounting], [trade], [friction], [between], [the], [u], [s], [and], [japan], [has], [raised], [fears], [among], [many], [of], [asia], ['], [s], [exporting], [nations], [that], [the], [row], [could], [inflict], [far], [reaching], [economic], [damage], [businessmen], [and], [officials], [said]]
# 1                                                                                                    [[they], [told], [reuter], [correspondents], [in], [asian], [capitals], [a], [u], [s], [move], [against], [japan], [might], [boost], [protectionist], [sentiment], [in], [the], [u], [s], [and], [lead], [to], [curbs], [on], [american], [imports], [of], [their], [products]]
# 2                                                                                                                                                             [[but], [some], [exporters], [said], [that], [while], [the], [conflict], [would], [hurt], [them], [in], [the], [long], [run], [in], [the], [short], [term], [tokyo], ['], [s], [loss], [might], [be], [their], [gain]]
# 3                  [[the], [u], [s], [has], [said], [it], [will], [impose], [mln], [dlrs], [of], [tariffs], [on], [imports], [of], [japanese], [electronics], [goods], [on], [april], [in], [retaliation], [for], [japan], ['], [s], [alleged], [failure], [to], [stick], [to], [a], [pact], [not], [to], [sell], [semiconductors], [on], [world], [markets], [at], [below], [cost]]
# 4                                                                                        [[unofficial], [japanese], [estimates], [put], [the], [impact], [of], [the], [tariffs], [at], [billion], [dlrs], [and], [spokesmen], [for], [major], [electronics], [firms], [said], [they], [would], [virtually], [halt], [exports], [of], [products], [hit], [by], [the], [new], [taxes]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             bigram  \
# 0  [[asian, exporters], [exporters, fear], [fear, damage], [damage, from], [from, u], [u, s], [s, japan], [japan, rift], [rift, mounting], [mounting, trade], [trade, friction], [friction, between], [between, the], [the, u], [u, s], [s, and], [and, japan], [japan, has], [has, raised], [raised, fears], [fears, among], [among, many], [many, of], [of, asia], [asia, '], [', s], [s, exporting], [exporting, nations], [nations, that], [that, the], [the, row], [row, could], [could, inflict], [inflict, far], [far, reaching], [reaching, economic], [economic, damage], [damage, businessmen], [businessmen, and], [and, officials], [officials, said]]
# 1                                                                                                                                                                                   [[they, told], [told, reuter], [reuter, correspondents], [correspondents, in], [in, asian], [asian, capitals], [capitals, a], [a, u], [u, s], [s, move], [move, against], [against, japan], [japan, might], [might, boost], [boost, protectionist], [protectionist, sentiment], [sentiment, in], [in, the], [the, u], [u, s], [s, and], [and, lead], [lead, to], [to, curbs], [curbs, on], [on, american], [american, imports], [imports, of], [of, their], [their, products]]
# 2                                                                                                                                                                                                                                                                                        [[but, some], [some, exporters], [exporters, said], [said, that], [that, while], [while, the], [the, conflict], [conflict, would], [would, hurt], [hurt, them], [them, in], [in, the], [the, long], [long, run], [run, in], [in, the], [the, short], [short, term], [term, tokyo], [tokyo, '], [', s], [s, loss], [loss, might], [might, be], [be, their], [their, gain]]
# 3                                  [[the, u], [u, s], [s, has], [has, said], [said, it], [it, will], [will, impose], [impose, mln], [mln, dlrs], [dlrs, of], [of, tariffs], [tariffs, on], [on, imports], [imports, of], [of, japanese], [japanese, electronics], [electronics, goods], [goods, on], [on, april], [april, in], [in, retaliation], [retaliation, for], [for, japan], [japan, '], [', s], [s, alleged], [alleged, failure], [failure, to], [to, stick], [stick, to], [to, a], [a, pact], [pact, not], [not, to], [to, sell], [sell, semiconductors], [semiconductors, on], [on, world], [world, markets], [markets, at], [at, below], [below, cost]]
# 4                                                                                                                                                              [[unofficial, japanese], [japanese, estimates], [estimates, put], [put, the], [the, impact], [impact, of], [of, the], [the, tariffs], [tariffs, at], [at, billion], [billion, dlrs], [dlrs, and], [and, spokesmen], [spokesmen, for], [for, major], [major, electronics], [electronics, firms], [firms, said], [said, they], [they, would], [would, virtually], [virtually, halt], [halt, exports], [exports, of], [of, products], [products, hit], [hit, by], [by, the], [the, new], [new, taxes]]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    trigram
# 0  [[asian, exporters, fear], [exporters, fear, damage], [fear, damage, from], [damage, from, u], [from, u, s], [u, s, japan], [s, japan, rift], [japan, rift, mounting], [rift, mounting, trade], [mounting, trade, friction], [trade, friction, between], [friction, between, the], [between, the, u], [the, u, s], [u, s, and], [s, and, japan], [and, japan, has], [japan, has, raised], [has, raised, fears], [raised, fears, among], [fears, among, many], [among, many, of], [many, of, asia], [of, asia, '], [asia, ', s], [', s, exporting], [s, exporting, nations], [exporting, nations, that], [nations, that, the], [that, the, row], [the, row, could], [row, could, inflict], [could, inflict, far], [inflict, far, reaching], [far, reaching, economic], [reaching, economic, damage], [economic, damage, businessmen], [damage, businessmen, and], [businessmen, and, officials], [and, officials, said]]
# 1                                                                                                                                                                                                                                                         [[they, told, reuter], [told, reuter, correspondents], [reuter, correspondents, in], [correspondents, in, asian], [in, asian, capitals], [asian, capitals, a], [capitals, a, u], [a, u, s], [u, s, move], [s, move, against], [move, against, japan], [against, japan, might], [japan, might, boost], [might, boost, protectionist], [boost, protectionist, sentiment], [protectionist, sentiment, in], [sentiment, in, the], [in, the, u], [the, u, s], [u, s, and], [s, and, lead], [and, lead, to], [lead, to, curbs], [to, curbs, on], [curbs, on, american], [on, american, imports], [american, imports, of], [imports, of, their], [of, their, products]]
# 2                                                                                                                                                                                                                                                                                                                                                                                                          [[but, some, exporters], [some, exporters, said], [exporters, said, that], [said, that, while], [that, while, the], [while, the, conflict], [the, conflict, would], [conflict, would, hurt], [would, hurt, them], [hurt, them, in], [them, in, the], [in, the, long], [the, long, run], [long, run, in], [run, in, the], [in, the, short], [the, short, term], [short, term, tokyo], [term, tokyo, '], [tokyo, ', s], [', s, loss], [s, loss, might], [loss, might, be], [might, be, their], [be, their, gain]]
# 3                                      [[the, u, s], [u, s, has], [s, has, said], [has, said, it], [said, it, will], [it, will, impose], [will, impose, mln], [impose, mln, dlrs], [mln, dlrs, of], [dlrs, of, tariffs], [of, tariffs, on], [tariffs, on, imports], [on, imports, of], [imports, of, japanese], [of, japanese, electronics], [japanese, electronics, goods], [electronics, goods, on], [goods, on, april], [on, april, in], [april, in, retaliation], [in, retaliation, for], [retaliation, for, japan], [for, japan, '], [japan, ', s], [', s, alleged], [s, alleged, failure], [alleged, failure, to], [failure, to, stick], [to, stick, to], [stick, to, a], [to, a, pact], [a, pact, not], [pact, not, to], [not, to, sell], [to, sell, semiconductors], [sell, semiconductors, on], [semiconductors, on, world], [on, world, markets], [world, markets, at], [markets, at, below], [at, below, cost]]
# 4                                                                                                                                                                                                                             [[unofficial, japanese, estimates], [japanese, estimates, put], [estimates, put, the], [put, the, impact], [the, impact, of], [impact, of, the], [of, the, tariffs], [the, tariffs, at], [tariffs, at, billion], [at, billion, dlrs], [billion, dlrs, and], [dlrs, and, spokesmen], [and, spokesmen, for], [spokesmen, for, major], [for, major, electronics], [major, electronics, firms], [electronics, firms, said], [firms, said, they], [said, they, would], [they, would, virtually], [would, virtually, halt], [virtually, halt, exports], [halt, exports, of], [exports, of, products], [of, products, hit], [products, hit, by], [hit, by, the], [by, the, new], [the, new, taxes]]

# %% [markdown]
# #### Tri-gram language model

# %%
from collections import Counter, defaultdict

#to create a placeholder for the model
model= defaultdict(lambda: defaultdict(lambda: 0))

#count frequency of co-occurence:
for i in range(len(df)):
    #for each trigram_pair:
    for w1,w2,w3 in create_trigram(df['clean_sentence'][i]):
        
        #count of occurence of w3 given w1 and w2
        model[(w1,w2)][w3]+=1

# %% [markdown]
# #### Converting to probabilistic model

# %%
for w1_w2 in model:
    total_count= float(sum(model[w1_w2].values())) #total possible occurences of the next word
    for w3 in model[w1_w2]: #for a given combination of w1_w2
        model[w1_w2][w3]/= total_count

# %%
dict(model['imports','of'])
# Out:
# {'their': 0.03333333333333333,
#  'japanese': 0.06666666666666667,
#  'u': 0.06666666666666667,
#  'raw': 0.03333333333333333,
#  'farm': 0.06666666666666667,
#  'essential': 0.03333333333333333,
#  'rice': 0.03333333333333333,
#  'soft': 0.03333333333333333,
#  'maize': 0.03333333333333333,
#  'microwave': 0.03333333333333333,
#  'tea': 0.03333333333333333,
#  'brazilian': 0.1,
#  'gifts': 0.03333333333333333,
#  'some': 0.03333333333333333,
#  'canadian': 0.03333333333333333,
#  'ec': 0.03333333333333333,
#  'billion': 0.1,
#  'textiles': 0.03333333333333333,
#  'apparel': 0.03333333333333333,
#  'all': 0.03333333333333333,
#  'soybeans': 0.03333333333333333,
#  'agricultural': 0.03333333333333333,
#  'machinery': 0.03333333333333333}

# %% [markdown]
# This is a tri-gram model that gives the probability of the next word (w3) based on the given two words.

# %%
#word with max probability
import operator
max(dict(model['imports','of']).items(), key=operator.itemgetter(1))[0]
# Out:
# 'brazilian'
